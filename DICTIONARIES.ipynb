# %%
list1 = ["cat", "dig", "monkey"]
for i, item in enumerate (list1):
    print(i, item)
# Out:
# 0 cat
# 1 dig
# 2 monkey

# %%
dict1 = {}
print(type(dict1))
# Out:
# <class 'dict'>

# %%
dict1 = {"name" : "elson" ,"age" : 24}
print(dict1["name"])
# Out:
# elson

# %%
dict1 = {"name" : ["john" , "mary"]}
print(dict1.get("name"))
# Out:
# ['john', 'mary']

# %%
dict1 = {"name" : ["john" , "mary"]}
print(list1)
# Out:
# ['cat', 'dig', 'monkey']

# %%
list2 = ["john" , "mary"]
dict1 = {"name" : [list2]}
print(list2),(dict1.get("name"))
# Out:
# ['john', 'mary']
# (None, [['john', 'mary']])

# %%
number = int(input("enter number:"))
total=number*2
print ("total is:", total)
# Out:
# enter number: 2
# total is: 4

# %%
number = int(input("enter number:"))
total=number*2
print ("total is:", total)
try:
    number = int(input("enter number:"))
except ValueError:
    print ("not a number")
# Out:
# enter number: 2
# total is: 4
# enter number: es
# not a number

# %%
numbers = [1,2]
try:
    print(numbers[2])
except Exception as e:
    print("not a number")
# Out:
# not a number

# %%
numbers = [1,2]
try:
    print(numbers[2])
except Exception as e:
    print("not a number")
finally:
    print()
